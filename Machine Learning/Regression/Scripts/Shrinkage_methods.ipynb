# %%
# import libraries
import numpy as np
import pandas as pd
from itertools import cycle
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression, RidgeCV, Ridge, LassoCV, ElasticNetCV, lasso_path, enet_path
np.set_printoptions(suppress=True)
rng = np.random.RandomState(seed=42)
pd.options.display.float_format = "{:.2f}".format

#import data 
boston = datasets.load_boston()
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
df_boston = pd.DataFrame(boston.data,columns=boston.feature_names)
df_boston['target'] = pd.Series(boston.target)
df_boston.head()
# Out:
#    CRIM    ZN  INDUS  CHAS  NOX   RM   AGE  DIS  RAD    TAX  PTRATIO      B  \
# 0  0.01 18.00   2.31  0.00 0.54 6.58 65.20 4.09 1.00 296.00    15.30 396.90
# 1  0.03  0.00   7.07  0.00 0.47 6.42 78.90 4.97 2.00 242.00    17.80 396.90
# 2  0.03  0.00   7.07  0.00 0.47 7.18 61.10 4.97 2.00 242.00    17.80 392.83
# 3  0.03  0.00   2.18  0.00 0.46 7.00 45.80 6.06 3.00 222.00    18.70 394.63
# 4  0.07  0.00   2.18  0.00 0.46 7.15 54.20 6.06 3.00 222.00    18.70 396.90
#
#    LSTAT  target
# 0   4.98   24.00
# 1   9.14   21.60
# 2   4.03   34.70
# 3   2.94   33.40
# 4   5.33   36.20

# %%
df_boston.describe()
# Out:
#         CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# count 506.00 506.00 506.00 506.00 506.00 506.00 506.00 506.00 506.00 506.00
# mean    3.61  11.36  11.14   0.07   0.55   6.28  68.57   3.80   9.55 408.24
# std     8.60  23.32   6.86   0.25   0.12   0.70  28.15   2.11   8.71 168.54
# min     0.01   0.00   0.46   0.00   0.39   3.56   2.90   1.13   1.00 187.00
# 25%     0.08   0.00   5.19   0.00   0.45   5.89  45.02   2.10   4.00 279.00
# 50%     0.26   0.00   9.69   0.00   0.54   6.21  77.50   3.21   5.00 330.00
# 75%     3.68  12.50  18.10   0.00   0.62   6.62  94.07   5.19  24.00 666.00
# max    88.98 100.00  27.74   1.00   0.87   8.78 100.00  12.13  24.00 711.00
#
#        PTRATIO      B  LSTAT  target
# count   506.00 506.00 506.00  506.00
# mean     18.46 356.67  12.65   22.53
# std       2.16  91.29   7.14    9.20
# min      12.60   0.32   1.73    5.00
# 25%      17.40 375.38   6.95   17.02
# 50%      19.05 391.44  11.36   21.20
# 75%      20.20 396.23  16.96   25.00
# max      22.00 396.90  37.97   50.00

# %%
df_boston.isna().sum() > 0
# Out:
# CRIM       False
# ZN         False
# INDUS      False
# CHAS       False
# NOX        False
# RM         False
# AGE        False
# DIS        False
# RAD        False
# TAX        False
# PTRATIO    False
# B          False
# LSTAT      False
# target     False
# dtype: bool

# %%
fig, ((ax1, ax2, ax3),( ax4, ax5, ax6),(ax7, ax8, ax9),(ax10,ax11,ax12),(ax13,ax14,ax15)) = plt.subplots(5, 3)
fig.set_size_inches(15,15)
ax1.plot(df_boston['target'],df_boston['CRIM'],"ob", alpha=0.3)
ax1.set_ylabel('CRIM')
ax2.plot(df_boston['target'],df_boston['ZN'],"ob", alpha=0.3) 
ax2.set_ylabel('ZN')
ax3.plot(df_boston['target'],df_boston['INDUS'],"ob", alpha=0.3)
ax3.set_ylabel('INDUS')
ax4.plot(df_boston['target'],df_boston['CHAS'],"ob", alpha=0.3) 
ax4.set_ylabel('CHAS')
ax5.plot(df_boston['target'],df_boston['NOX'],"ob", alpha=0.3) 
ax5.set_ylabel('NOX')
ax6.plot(df_boston['target'],df_boston['RM'],"ob", alpha=0.3) 
ax6.set_ylabel('RM')
ax7.plot(df_boston['target'],df_boston['AGE'],"ob", alpha=0.3) 
ax7.set_ylabel('AGE')
ax8.plot(df_boston['target'],df_boston['DIS'],"ob", alpha=0.3) 
ax8.set_ylabel('DIS')
ax9.plot(df_boston['target'],df_boston['RAD'],"ob", alpha=0.3) 
ax9.set_ylabel('RAD')
ax10.plot(df_boston['target'],df_boston['TAX'],"ob", alpha=0.3) 
ax10.set_ylabel('TAX')
ax11.plot(df_boston['target'],df_boston['PTRATIO'],"ob", alpha=0.3) 
ax11.set_ylabel('PTRATIO')
ax12.plot(df_boston['target'],df_boston['B'],"ob", alpha=0.3) 
ax12.set_ylabel('B')
ax13.plot(df_boston['target'],df_boston['LSTAT'],"ob", alpha=0.3) 
ax13.set_ylabel('LSTAT')
# Out:
# Text(0, 0.5, 'LSTAT')

# %%
corr = df_boston.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col0,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col1,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col2,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row3_col3,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row4_col4,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row5_col5,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row6_col6,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row7_col7,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row8_col8,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row9_col9,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row10_col10,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row11_col11,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row12_col12,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row13_col13{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col1{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col2{
#             background-color:  #f7bca1;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col3{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col4{
#             background-color:  #f7b599;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col5{
#             background-color:  #8badfd;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col6,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col13{
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col7,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row11_col4,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row11_col10{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col8{
#             background-color:  #f49a7b;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col9,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col8,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row8_col0{
#             background-color:  #f6a283;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col10{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col11,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row13_col9{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col12{
#             background-color:  #f7b194;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row0_col13,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row9_col5{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col0{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col2,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col6,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row8_col3{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col3{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col4,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col9{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col5,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col0{
#             background-color:  #edd1c2;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col7,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row9_col4,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row13_col5{
#             background-color:  #ec7f63;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col8,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row5_col0{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col10,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row9_col3,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row13_col8{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col11{
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row1_col12,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row5_col2,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row6_col3,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row10_col11{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col1,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row7_col3{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col3,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row8_col1{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col4{
#             background-color:  #e0654f;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col5,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row7_col12{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col6{
#             background-color:  #ee8669;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col7,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row4_col1,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row11_col8{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col9{
#             background-color:  #ea7b60;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col10,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row13_col1{
#             background-color:  #f1cdba;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col11,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row11_col9,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row12_col3{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col12,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row6_col12,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row12_col6{
#             background-color:  #f29072;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row2_col13{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row3_col0{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row3_col1{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row3_col2{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row3_col4{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row3_col5{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row3_col6{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row3_col7{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row3_col8,#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row3_col9{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row3_col10{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row3_col11{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_f722a93e_27ca_11eb_aa23_d8cb8aecf7f1row3_col12{
#             backgro

# %% [markdown]
# Let's create a basic preprocessing pipeline, here we want to accomplish threemain objectives:
#
# 1. Transform categorical variables with one hot encoders and drop one of the categeries, this category will be used to interpret the results.
# 2. Normalize the values for the numerical variables

# %%
categorical_columns = ['CHAS']
numerical_columns = ['CRIM','ZN','INDUS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT']

X = df_boston[categorical_columns + numerical_columns]
y=df_boston['target']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
categorical_pipe = Pipeline([
    ('onehot', OneHotEncoder(drop='first'))
])

numerical_pipe = Pipeline([
    ('std_scaler', StandardScaler())
])

preprocessing = ColumnTransformer([
    ('num', numerical_pipe, numerical_columns),
    ('cat', categorical_pipe, categorical_columns),
])

clf_lr = Pipeline([
    ('preprocess', preprocessing),
    ('L_regressor',LinearRegression()),
])

clf_ridge = Pipeline([
    ('preprocess', preprocessing),
    ('L_regressor',RidgeCV(alphas=np.logspace(-2, 10, 200), cv=10)),
]) 

clf_lasso = Pipeline([
    ('preprocess', preprocessing),
    ('L_regressor',LassoCV(eps = 5e-8, cv=10)),
]) 

clf_enet = Pipeline([
    ('preprocess', preprocessing),
    ('L_regressor',ElasticNetCV(eps = 5e-8, cv=10)),
])

# %%
clf_lr.fit(X_train,y_train)
y_pred_lr = clf_lr.predict(X_test)
print(clf_lr.named_steps['L_regressor'].coef_)
print("LR train score: %0.6f" % clf_lr.score(X_train, y_train))
print("LR test score: %0.6f" % clf_lr.score(X_test, y_test))

clf_ridge.fit(X_train,y_train)
y_pred_ridge = clf_ridge.predict(X_test)
print(clf_ridge.named_steps['L_regressor'].coef_)
print("Ridge train score: %0.6f" % clf_ridge.score(X_train, y_train))
print("Ridge test score: %0.6f" % clf_ridge.score(X_test, y_test))

clf_lasso.fit(X_train,y_train)
y_pred_lasso = clf_lasso.predict(X_test)
print(clf_lasso.named_steps['L_regressor'].coef_)
print("Lasso train score: %0.6f" % clf_lasso.score(X_train, y_train))
print("Lasso test score: %0.6f" % clf_lasso.score(X_test, y_test))

clf_enet.fit(X_train,y_train)
y_pred_enet = clf_lasso.predict(X_test)
print(clf_enet.named_steps['L_regressor'].coef_)
print("Enet train score: %0.6f" % clf_enet.score(X_train, y_train))
print("Enet test score: %0.6f" % clf_enet.score(X_test, y_test))
# Out:
# [-0.98858032  0.86793276  0.40502822 -1.90009974  2.80813518 -0.35866856
#  -3.04553498  2.03276074 -1.36400909 -2.0825356   1.04125684 -3.92628626
#   3.23866812]
# LR train score: 0.739234
# LR test score: 0.726157
# [-0.8715974   0.65362238  0.15928058 -1.40412694  2.89990891 -0.35272457
#  -2.52262399  1.30440983 -0.8040135  -1.94820489  1.03854791 -3.76809479
#   2.11120909]
# Ridge train score: 0.735727
# Ridge test score: 0.723126
# [-0.98857928  0.86793104  0.4050251  -1.90009715  2.8081354  -0.35866786
#  -3.04553258  2.03275475 -1.36400333 -2.0825349   1.04125653 -3.92628653
#   3.23866467]
# Lasso train score: 0.739234
# Lasso test score: 0.726157
# [-0.94842005  0.79524644  0.2999359  -1.76004895  2.83294132 -0.34558115
#  -2.91149908  1.7794992  -1.14020153 -2.04720797  1.03746722 -3.91044817
#   2.9350093 ]
# Enet train score: 0.738951
# Enet test score: 0.725702

# %%
n_alphas = 200
alphas = np.logspace(-2, 10, n_alphas)
coefs = []
for a in alphas:
    ridge = Ridge(alpha=a, fit_intercept=False)
    ridge.fit(X, y)
    coefs.append(ridge.coef_)

# %%
ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale('log')
ax.set_xlim(ax.get_xlim()[::-1])  # reverse axis
plt.xlabel('alpha')
plt.ylabel('weights')
plt.title('Ridge coefficients as a function of the regularization')
plt.axis('tight')
plt.axvline(clf_ridge.named_steps['L_regressor'].alpha_, c='red')

# %%
eps = 5e-8  # the smaller it is the longer is the path
alphas_lasso, coefs_lasso, _ = lasso_path(X, y, eps=eps, fit_intercept=False)
alphas_positive_lasso, coefs_positive_lasso, _ = lasso_path(
    X, y, eps=eps, positive=True, fit_intercept=False)
alphas_enet, coefs_enet, _ = enet_path(
    X, y, eps=eps, l1_ratio=0.8, fit_intercept=False)
alphas_positive_enet, coefs_positive_enet, _ = enet_path(
    X, y, eps=eps, l1_ratio=0.8, positive=True, fit_intercept=False)

plt.figure(1)
colors = cycle(['C0', 'C1', 'C2', 'C3', 'C4', 'C5','C6','C7','C8','C9','C10','C11','C12','C13'])
neg_log_alphas_lasso = -np.log10(alphas_lasso)
neg_log_alphas_enet = -np.log10(alphas_enet)
for coef_l, coef_e, c in zip(coefs_lasso, coefs_enet, colors):
    l1 = plt.plot(neg_log_alphas_lasso, coef_l, c=c)
    l2 = plt.plot(neg_log_alphas_enet, coef_e, linestyle='--', c=c)

plt.xlabel('-Log(alpha)')
plt.ylabel('coefficients')
plt.title('Lasso and Elastic-Net Paths')
plt.legend((l1[-1], l2[-1]), ('Lasso', 'Elastic-Net'), loc='lower left')
plt.axis('tight')
plt.axvline(clf_lasso.named_steps['L_regressor'].alpha_, c='red')
plt.axvline(clf_enet.named_steps['L_regressor'].alpha_, c='red',  linestyle='--' )
